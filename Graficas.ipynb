# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
dataset = pd.read_pickle("archivo_dataset_graficar.pkl")
resultado = pd.read_pickle("archivo_prueba_graficar.pkl")

# %%
dataset.head()
# Out:
#    cod_est sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0      289   M   18       U     LE3       A     4     4  teacher  teacher
# 1       22   M   16       U     LE3       T     4     2  teacher    other
# 2       35   F   15       U     GT3       T     2     3    other    other
# 3      303   F   17       U     GT3       T     3     2   health   health
# 4      253   M   16       R     GT3       T     2     1    other    other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  reputation   mother           1          2         0        no    yes  yes
# 1      course   mother           1          2         0        no     no   no
# 2       other   father           2          1         0        no    yes   no
# 3  reputation   father           1          4         0        no    yes  yes
# 4      course   mother           2          1         0        no     no   no
#
# ...

# %%
resultado.head()
# Out:
#    cod_est sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      231   M   17       R     GT3       T     2     2     other     other
# 1      155   M   15       R     GT3       T     2     3   at_home  services
# 2      182   F   17       U     GT3       T     2     4  services  services
# 3      116   M   15       U     GT3       T     4     4     other   teacher
# 4      108   M   15       R     GT3       T     4     4     other     other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0      course   father           2          2         0        no    yes  yes
# 1      course   mother           1          2         0       yes     no  yes
# 2  reputation   father           1          2         0        no    yes   no
# 3  reputation   father           2          2         0        no    yes   no
# 4        home   father           4          4         0        no    yes  yes
#
# ...

# %%
resultado_general = resultado
resultado_predicc = resultado.loc[resultado['prediccion'] == 0]

# %%
def graficas(dataframe):
    
    #Filtros
    #general = pd.DataFrame(dataframe.groupby('prediccion')['cod_est'].nunique())
    sexo = pd.DataFrame(dataframe.groupby('sex')['cod_est'].nunique()).reset_index()
    edad = pd.DataFrame(dataframe.groupby('age')['cod_est'].nunique()).reset_index()
    procedencia = pd.DataFrame(dataframe.groupby('address')['cod_est'].nunique()).reset_index()
    tam_familia = pd.DataFrame(dataframe.groupby('famsize')['cod_est'].nunique()).reset_index()
    
    
    # Graficas
    sexo = sexo.plot(x="sex", y="cod_est", kind='bar')
    edad = edad.plot(x="age", y="cod_est", kind='bar')
    procedencia = procedencia.plot(x="address", y="cod_est", kind='bar')
    tam_familia = tam_familia.plot(x="famsize", y="cod_est", kind='bar')
    #print(general)
    #general = general.plot(kind="bar")

# %%
graficas(resultado_predicc)
